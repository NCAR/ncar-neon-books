# %% [markdown]
# # CTSM Simulations at NEON Tower Sites -- Tutorial
#
# This tutorial is an introduction to running the Community Terrestrial Systems Model (CTSM) at NEON tower sites.  It will guide you through running a simulation and provides example visualization of the simulation results.
#
# There are several configuration options of CTSM, and throughout this tutorial we will use the Community Land Model (CLM) configuration which is the climate and biogeochemistry mode of CTSM. Throughout the rest of this tutorial, we refer to the model as CLM and will use version 5.1 with active biogeochemistry (CLM5.1-BGC).
# ***

# %% [markdown]
# ## In this tutorial
#
# The tutorial has several components. Below you will find steps to:
# 1. Set up and run a simulation
# 2. Locate CLM model data
# 3. Look at a plot of simulated soil temperature data

# %% [markdown]
# ***
# **The tutorial uses a Jupyter Notebook.** A Jupyter Notebook is an interactive computing environment that enables the creation and sharing of documents that contain discrete cells of text or documentation and executable code, including plots. It allows users to access, run, and edit the code in a browser. To interact with this notebook:
#
# - Execute or "run" cells of executable code (cells denoted with '[ ]:') using the play button in the menu at the top (see below image)
#
# - The results of running code, such as plots, will appear below that cell
#
# - Each step must be followed in order, otherwise you may encounter errors
#
# ![run cell](https://problemsolvingwithpython.com/02-Jupyter-Notebooks/images/run_cell.png)
#
# For more information on Jupyter notebooks please see the [Jupyter Notebook Quick Start Guide](https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html).
# ***

# %% [markdown]
# <h2> 1. Set up and run a simulation</h2>
#
# *This step guides you through running a CLM model simulation for a NEON flux tower using meteorology observations from the tower. Here, the many steps to run CLM are condensed into a single function. If you would like a more advanced tutorial to change the model configuration or code, please see [tutorial coming soon] for additional instructions.* <br>
#
# ***
# <h4>1.1 Select a NEON tower site to simulate.</h4>
#
# NEON towers currently available for simulation include:
#
# >ABBY, BART, BLAN, CPER, DCFS, DSNY, GRSM, HARV, JERC, JORN, KONZ, MOAB, NOGP, OAES, ORNL, OSBS, SCBI, SERC, SOAP, SRER, STEI, TALL, TREE, UKFS, UNDE, WOOD.
#
# The [NEON website](https://www.neonscience.org/field-sites/explore-field-sites) describes tower sites in more detail.
#
# Before running the below code, keep in mind:
# - The executable code below selects the **ABBY** site for simulation. If you would like to simulate a different tower, select the NEON tower from the above list and change the 4-character site name inside the quotes below.
# - The site must be defined correctly so you do not get an error in the next step.
#     - use all capital letters
#     - double-check that the letters match one of the above site names
#
# *Execute the the cell below by clicking on the play button in the menu bar above.*

# %%
#Change the 4-character NEON site below.
neon_site= "SCBI  SERC  SOAP  SRER  STEI  TALL  TREE  UKFS  UNDE  WOOD"

import os
os.environ['site'] = neon_site

# %% [markdown]
# ***
# <h4>1.2 Create and run a NEON tower site simulation.</h4>
#
# The executable code below runs a python script, `run_neon.py`. This script:
#
# * creates (`create_newcase`)
# * sets up (`case.setup`)
# * compiles (`case.build`)
# * runs (`case.submit`)
#
# a simulation for the tower site you specified above for all years that tower meteorology data are available.
#
# *Run the cell below.* Note that this step downloads the input data (~7GB) required for the model simulation. It may take several minutes to run, so please be patient. Many things will print below the cell as data are downloaded and the model compiles. You might see lines print that say 'ERROR 404: Not Found' and this is ok. You will also likely notice that many files are moved after the simulation completes.
#
# *Note: we are working to update this code so that it prints fewer lines*

# %%
run_neon --neon-sites $site --output-root ~/CLM-NEON --overwrite
# Out:
# Download finished successfully for listing.csv .
# ---- building a base case -------
# base_case_name : SCBI
# user_mods_dir  : /opt/ncar/cesm2/cime_config/usermods_dirs/NEON/SCBI
# ---- creating a base case -------
# Compset longname is 2000_DATM%1PT_CLM51%BGC_SICE_SOCN_SROF_SGLC_SWAV
# Compset specification file is /opt/ncar/cesm2/cime_config/config_compsets.xml
# Automatically adding SESP to compset
# Compset forcing is 1972-2004
# ATM component is  Data driven ATM single point tower site data set
# LND component is clm5.1:BGC (vert. resol. CN and methane):
# ICE component is Stub ice component
# OCN component is Stub ocn component
# ROF component is Stub river component
# GLC component is Stub glacier (land ice) component
# WAV component is Stub wave component
# ESP component is Stub external system processing (ESP) component
# Pes     specification file is /opt/ncar/cesm2/cime_config/config_pes.xml
# Compset specific settings: name is RUN_STARTDATE and value is 2000-01-01
# Could not find machine match for 'e98ffc04cc4a' or 'e98ffc04cc4a'
# Machine is container
# Variable MAX_GPUS_PER_NODE not defined for machine container
# Pes setting: grid match    is l%1x1|l%CLM_USRDAT
# Pes setting: grid          is a%CLM_USRDAT_l%CLM_USRDAT_oi%null_r%null_g%null_w%null_z%null_m%null
# Pes setting: compset       is 2000_DATM%1PT_CLM51%BGC_SICE_SOCN_SROF_SGLC_SWAV_SESP
# Pes setting: tasks       is {'NTASKS_ATM': 1, 'NTASKS_LND': 1, 'NTASKS_ROF': 1, 'NTASKS_ICE': 1, 'NTASKS_OCN': 1, 'NTASKS_GLC': 1, 'NTASKS_WAV': 1, 'NTASKS_CPL': 1}
# Pes setting: threads     is {'NTHRDS_ATM': 1, 'NTHRDS_LND': 1, 'NTHRDS_ROF': 1, 'NTHRDS_ICE': 1, 'NTHRDS_OCN': 1, 'NTHRDS_GLC': 1, 'NTHRDS_WAV': 1, 'NTHRDS_CPL': 1}
# Pes setting: rootpe      is {'ROOTPE_ATM': 0, 'ROOTPE_LND': 0, 'ROOTPE_ROF': 0, 'ROOTPE_ICE': 0, 'ROOTPE_OCN': 0, 'ROOTPE_GLC': 0, 'ROOTPE_WAV': 0, 'ROOTPE_CPL': 0}
# Pes setting: pstrid      is {}
# Pes other settings: {}
# Pes comments: none
# setting additional fields from config_pes: {}
#  Compset is: 2000_DATM%1PT_CLM51%BGC_SICE_SOCN_SROF_SGLC_SWAV_SESP
#  Grid is: a%CLM_USRDAT_l%CLM_USRDAT_oi%null_r%null_g%null_w%null_z%null_m%null
#  Components in compset are: ['datm', 'clm', 'sice', 'socn', 'srof', 'sglc', 'swav', 'sesp']
# No project info available
# No charge_account info available, using value from PROJECT
# cesm model version found: branch_tags/neon.n04_ctsm5.1.dev053
# Batch_system_type is none
#  Creating Case directory /home/user/CLM-NEON/SCBI
# Adding user mods directory /opt/ncar/cesm2/cime_config/usermods_dirs/NEON/SCBI
# Adding user mods directory /opt/ncar/cesm2/cime_config/usermods_dirs/NEON/defaults
# RUN: /home/user/CLM-NEON/SCBI/shell_commands
# FROM: /home/user/CLM-NEON/SCBI
# ---- base case created ------
# ---- base case setup ------
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# /home/user/CLM-NEON/SCBI/env_mach_specific.xml already exists, delete to replace
# /home/user/CLM-NEON/SCBI/env_mach_specific.xml already exists, delete to replace
# Creating batch scripts
# Writing case.run script from input template /opt/ncar/cesm2/cime/config/cesm/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /opt/ncar/cesm2/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run
# ---- base case build ------
# Building case in directory /home/user/CLM-NEON/SCBI
# sharedlib_only is False
# model_only is False
# Generating component namelists as part of build
#   2021-10-26 13:30:41 atm
# Create namelist for component datm
#    Calling /opt/ncar/cesm2/components/cdeps/datm/cime_config/buildnml
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# WARNING: No .input_data_list files found in dir 'Buildconf'
# Using protocol wget with user None and passwd None
# SUCCESS
#
# Found tower data for 2018-01-01 00:00:00 through 2021-06-01 00:00:00
#   2021-10-26 13:30:44 lnd
# Create namelist for component clm
#    Calling /opt/ncar/cesm2/cime_config/buildnml
#   2021-10-26 13:30:44 ice
# Create namelist for component sice
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/sice/cime_config/buildnml
#   2021-10-26 13:30:44 ocn
# Create namelist for component socn
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/socn/cime_config/buildnml
#   2021-10-26 13:30:44 rof
# Create namelist for component srof
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/srof/cime_config/buildnml
#   2021-10-26 13:30:44 glc
# Create namelist for component sglc
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/sglc/cime_config/buildnml
#   2021-10-26 13:30:44 wav
# Create namelist for component swav
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/swav/cime_config/buildnml
#   2021-10-26 13:30:44 esp
# Create namelist for component sesp
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/sesp/cime_config/buildnml
#   2021-10-26 13:30:44 cpl
# Create namelist for component drv
#    Calling /opt/ncar/cesm2/components/cmeps/cime_config/buildnml
# Writing nuopc_runseq for components ['CPL', 'ATM', 'LND']
# Building gptl with output to file /home/user/CLM-NEON/SCBI/bld/gptl.bldlog.211026-133041
#    Calling /opt/ncar/cesm2/cime/src/build_scripts/buildlib.gptl
# Component gptl build complete with 1 warnings
# Building mct with output to file /home/user/CLM-NEON/SCBI/bld/mct.bldlog.211026-133041
#    Calling /opt/ncar/cesm2/cime/src/build_scripts/buildlib.mct
# Building pio with output to file /home/user/CLM-NEON/SCBI/bld/pio.bldlog.211026-133041
#    Calling /opt/ncar/cesm2/cime/src/build_scripts/buildlib.pio
# Component pio build complete with 10 warnings
# Building csm_share with output to file /home/user/CLM-NEON/SCBI/bld/csm_share.bldlog.211026-133041
#    Calling /opt/ncar/cesm2/share/buildlib.csm_share
# Component csm_share build complete with 4 warnings
# Building CDEPS with output to file /home/user/CLM-NEON/SCBI/bld/CDEPS.bldlog.211026-133041
#    Calling /opt/ncar/cesm2/components/cdeps/cime_config/buildlib
#          - Building clm library
# Building lnd with output to /home/user/CLM-NEON/SCBI/bld/lnd.bldlog.211026-133041
# Component lnd build complete with 2 warnings
# clm built in 73.100629 seconds
#          - Building atm Library
# Building atm with output to /home/user/CLM-NEON/SCBI/bld/atm.bldlog.211026-133041
# datm built in 1.042085 seconds
# Building cesm from /opt/ncar/cesm2/components/cmeps/cime_config/buildexe with output to /home/user/CLM-NEON/SCBI/bld/cesm.bldlog.211026-133041
# Total build time: 201.300037 seconds
# MODEL BUILD HAS FINISHED SUCCESSFULLY
# Time required to building the base case: 201.3068814277649 s.
# -----------------------------------
# Running CTSM for neon site : SCBI
# ---- removing the existing case -------
# -----------------------------------
# Running CTSM for neon site : SERC
# ---- cloning the base case in /home/user/CLM-NEON/SERC.transient
# Adding user mods directory /opt/ncar/cesm2/cime_config/usermods_dirs/NEON/SERC
# Adding user mods directory /opt/ncar/cesm2/cime_config/usermods_dirs/NEON/defaults
# RUN: /home/user/CLM-NEON/SERC.transient/shell_commands
# FROM: /home/user/CLM-NEON/SERC.transient
#  Successfully created new case SERC.transient from clone case SCBI
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# /home/user/CLM-NEON/SERC.transient/env_mach_specific.xml already exists, delete to replace
# /home/user/CLM-NEON/SERC.transient/env_mach_specific.xml already exists, delete to replace
# Creating batch scripts
# Writing case.run script from input template /opt/ncar/cesm2/cime/config/cesm/machines/template.case.run
# Creating file .case.run
# Writing case.st_archive script from input template /opt/ncar/cesm2/cime/config/cesm/machines/template.st_archive
# Creating file case.st_archive
# If an old case build already exists, might want to run 'case.build --clean' before building
# You can now run './preview_run' to get more info on how your case will be run
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
#   2021-10-26 13:34:07 atm
# Create namelist for component datm
#    Calling /opt/ncar/cesm2/cime/../components/cdeps/datm/cime_config/buildnml
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Using protocol wget with user None and passwd None
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/ctsm.input_data_list'
# Model ctsm no file specified for flanduse_timeseries
# Model ctsm missing file finidat = '/home/user/inputdata/lnd/clm2/initdata_map/clmi.I2000Clm50BgcCrop.2011-01-01.1.9x2.5_gx1v7_gl4_simyr2000_c190312.nc'
# Trying to download file: 'lnd/clm2/initdata_map/clmi.I2000Clm50BgcCrop.2011-01-01.1.9x2.5_gx1v7_gl4_simyr2000_c190312.nc' to path '/home/user/inputdata/lnd/clm2/initdata_map/clmi.I2000Clm50BgcCrop.2011-01-01.1.9x2.5_gx1v7_gl4_simyr2000_c190312.nc' using WGET protocol.
# wget failed with output:  and errput --2021-10-26 13:34:07--  https://s3.data.neonscience.org/neon-ncar/NEON/lnd/clm2/initdata_map/clmi.I2000Clm50BgcCrop.2011-01-01.1.9x2.5_gx1v7_gl4_simyr2000_c190312.nc
# Resolving s3.data.neonscience.org (s3.data.neonscience.org)... 129.19.148.21
# Connecting to s3.data.neonscience.org (s3.data.neonscience.org)|129.19.148.21|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-10-26 13:34:07 ERROR 404: Not Found.
#
# SUCCESS
#
# Found tower data for 2018-01-01 00:00:00 through 2021-06-01 00:00:00
# varname datafiles is already in stream mod dictionary
# varname year_first is already in stream mod dictionary
# varname year_last is already in stream mod dictionary
# varname year_align is already in stream mod dictionary
# varname dtlimit is already in stream mod dictionary
#   2021-10-26 13:34:10 lnd
# Create namelist for component clm
#    Calling /opt/ncar/cesm2/cime/../cime_config/buildnml
#   2021-10-26 13:34:10 ice
# Create namelist for component sice
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/sice/cime_config/buildnml
#   2021-10-26 13:34:10 ocn
# Create namelist for component socn
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/socn/cime_config/buildnml
#   2021-10-26 13:34:10 rof
# Create namelist for component srof
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/srof/cime_config/buildnml
#   2021-10-26 13:34:10 glc
# Create namelist for component sglc
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/sglc/cime_config/buildnml
#   2021-10-26 13:34:10 wav
# Create namelist for component swav
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/swav/cime_config/buildnml
#   2021-10-26 13:34:10 esp
# Create namelist for component sesp
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/sesp/cime_config/buildnml
#   2021-10-26 13:34:10 cpl
# Create namelist for component drv
#    Calling /opt/ncar/cesm2/cime/../components/cmeps/cime_config/buildnml
# Writing nuopc_runseq for components ['CPL', 'ATM', 'LND']
# Checking server https://s3.data.neonscience.org/neon-ncar/NEON/ with protocol wget
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Using protocol wget with user  and passwd
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/ctsm.input_data_list'
# Model ctsm no file specified for flanduse_timeseries
# Model ctsm missing file fsurdat = '/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_hist_78pfts_CMIP6_simyr2000_SERC_c210831.nc'
# Trying to download file: 'lnd/clm2/surfdata_map/NEON/surfdata_hist_78pfts_CMIP6_simyr2000_SERC_c210831.nc' to path '/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_hist_78pfts_CMIP6_simyr2000_SERC_c210831.nc' using WGET protocol.
# wget failed with output:  and errput --2021-10-26 13:34:11--  https://s3.data.neonscience.org/neon-ncar/NEON/lnd/clm2/surfdata_map/NEON/surfdata_hist_78pfts_CMIP6_simyr2000_SERC_c210831.nc
# Resolving s3.data.neonscience.org (s3.data.neonscience.org)... 129.19.148.21
# Connecting to s3.data.neonscience.org (s3.data.neonscience.org)|129.19.148.21|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-10-26 13:34:11 ERROR 404: Not Found.
#
# Model ctsm missing file finidat = '/home/user/CLM-NEON/SERC.transient/run/inputdata/lnd/ctsm/initdata/SERC.2021-09-02.clm2.r.0268-01-01-00000.nc'
# Creating directory /home/user/CLM-NEON/SERC.transient/run/inputdata/lnd/ctsm/initdata
# Trying to download file: 'lnd/ctsm/initdata/SERC.2021-09-02.clm2.r.0268-01-01-00000.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/lnd/ctsm/initdata/SERC.2021-09-02.clm2.r.0268-01-01-00000.nc' using WGET protocol.
# SUCCESS
#
# Loading input file list: 'Buildconf/datm.input_data_list'
# Model datm missing file file1 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-01.nc'
# Creating directory /home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2018-01.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-01.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file2 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-02.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2018-02.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-02.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file3 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-03.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2018-03.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-03.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file4 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-04.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2018-04.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-04.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file5 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-05.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2018-05.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-05.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file6 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-06.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2018-06.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-06.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file7 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-07.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2018-07.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-07.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file8 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-08.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2018-08.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-08.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file9 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-09.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2018-09.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-09.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file10 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-10.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2018-10.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-10.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file11 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-11.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2018-11.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-11.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file12 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-12.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2018-12.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2018-12.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file13 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-01.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2019-01.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-01.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file14 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-02.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2019-02.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-02.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file15 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-03.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2019-03.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-03.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file16 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-04.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2019-04.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-04.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file17 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-05.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2019-05.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-05.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file18 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-06.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2019-06.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-06.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file19 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-07.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2019-07.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-07.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file20 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-08.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2019-08.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-08.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file21 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-09.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2019-09.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-09.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file22 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-10.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2019-10.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-10.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file23 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-11.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2019-11.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-11.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file24 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-12.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2019-12.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2019-12.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file25 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-01.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2020-01.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-01.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file26 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-02.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2020-02.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-02.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file27 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-03.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2020-03.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-03.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file28 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-04.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2020-04.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-04.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file29 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-05.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2020-05.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-05.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file30 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-06.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2020-06.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-06.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file31 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-07.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2020-07.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-07.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file32 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-08.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2020-08.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-08.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file33 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-09.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2020-09.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-09.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file34 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-10.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2020-10.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-10.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file35 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-11.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2020-11.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-11.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file36 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-12.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2020-12.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2020-12.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file37 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2021-01.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2021-01.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2021-01.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file38 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2021-02.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2021-02.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2021-02.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file39 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2021-03.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2021-03.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2021-03.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file40 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2021-04.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2021-04.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2021-04.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file41 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2021-05.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2021-05.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2021-05.nc' using WGET protocol.
# SUCCESS
#
# Model datm missing file file42 = '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2021-06.nc'
# Trying to download file: 'atm/cdeps/v1/SERC/SERC_atm_2021-06.nc' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata/atm/cdeps/v1/SERC/SERC_atm_2021-06.nc' using WGET protocol.
# SUCCESS
#
#   2021-10-26 13:34:25 atm
# Create namelist for component datm
#    Calling /opt/ncar/cesm2/cime/../components/cdeps/datm/cime_config/buildnml
# Found tower data for 2018-01-01 00:00:00 through 2021-06-01 00:00:00
# varname datafiles is already in stream mod dictionary
# varname year_first is already in stream mod dictionary
# varname year_last is already in stream mod dictionary
# varname year_align is already in stream mod dictionary
# varname dtlimit is already in stream mod dictionary
#   2021-10-26 13:34:25 lnd
# Create namelist for component clm
#    Calling /opt/ncar/cesm2/cime/../cime_config/buildnml
#   2021-10-26 13:34:26 ice
# Create namelist for component sice
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/sice/cime_config/buildnml
#   2021-10-26 13:34:26 ocn
# Create namelist for component socn
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/socn/cime_config/buildnml
#   2021-10-26 13:34:26 rof
# Create namelist for component srof
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/srof/cime_config/buildnml
#   2021-10-26 13:34:26 glc
# Create namelist for component sglc
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/sglc/cime_config/buildnml
#   2021-10-26 13:34:26 wav
# Create namelist for component swav
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/swav/cime_config/buildnml
#   2021-10-26 13:34:26 esp
# Create namelist for component sesp
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/sesp/cime_config/buildnml
#   2021-10-26 13:34:26 cpl
# Create namelist for component drv
#    Calling /opt/ncar/cesm2/cime/../components/cmeps/cime_config/buildnml
# Writing nuopc_runseq for components ['CPL', 'ATM', 'LND']
# Checking that inputdata is available as part of case submission
# Checking server https://s3.data.neonscience.org/neon-ncar/NEON/ with protocol wget
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Using protocol wget with user  and passwd
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/ctsm.input_data_list'
# Model ctsm no file specified for flanduse_timeseries
# Model ctsm missing file fsurdat = '/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_hist_78pfts_CMIP6_simyr2000_SERC_c210831.nc'
# Trying to download file: 'lnd/clm2/surfdata_map/NEON/surfdata_hist_78pfts_CMIP6_simyr2000_SERC_c210831.nc' to path '/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_hist_78pfts_CMIP6_simyr2000_SERC_c210831.nc' using WGET protocol.
# wget failed with output:  and errput --2021-10-26 13:34:26--  https://s3.data.neonscience.org/neon-ncar/NEON/lnd/clm2/surfdata_map/NEON/surfdata_hist_78pfts_CMIP6_simyr2000_SERC_c210831.nc
# Resolving s3.data.neonscience.org (s3.data.neonscience.org)... 129.19.148.21
# Connecting to s3.data.neonscience.org (s3.data.neonscience.org)|129.19.148.21|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-10-26 13:34:26 ERROR 404: Not Found.
#
# Loading input file list: 'Buildconf/datm.input_data_list'
# Checking server None with protocol None
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Client protocol None not enabled
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/ctsm.input_data_list'
# Model ctsm no file specified for flanduse_timeseries
# Model ctsm missing file fsurdat = '/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_hist_78pfts_CMIP6_simyr2000_SERC_c210831.nc'
# Loading input file list: 'Buildconf/datm.input_data_list'
# Client protocol gftp not enabled
# Using protocol wget with user anonymous and passwd user@example.edu
# Trying to download file: '../inputdata_checksum.dat' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata_checksum.dat.raw' using WGET protocol.
# SUCCESS
#
# Using protocol ftp with user anonymous and passwd user@example.edu
# server address ftp.cgd.ucar.edu root path cesm/inputdata
# Trying to download file: '../inputdata_checksum.dat' to path '/home/user/CLM-NEON/SERC.transient/run/inputdata_checksum.dat.raw' using FTP protocol.
# Using protocol svn with user  and passwd
# Client protocol None not enabled
# Checking server ftp://gridanon.cgd.ucar.edu:2811/cesm/inputdata/ with protocol gftp
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Client protocol gftp not enabled
# Checking server ftp://ftp.cgd.ucar.edu/cesm/inputdata/ with protocol wget
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Using protocol wget with user anonymous and passwd user@example.edu
# Loading input file list: 'Buildconf/cpl.input_data_list'
# Loading input file list: 'Buildconf/ctsm.input_data_list'
# Model ctsm no file specified for flanduse_timeseries
# Model ctsm missing file fsurdat = '/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_hist_78pfts_CMIP6_simyr2000_SERC_c210831.nc'
# Trying to download file: 'lnd/clm2/surfdata_map/NEON/surfdata_hist_78pfts_CMIP6_simyr2000_SERC_c210831.nc' to path '/home/user/inputdata/lnd/clm2/surfdata_map/NEON/surfdata_hist_78pfts_CMIP6_simyr2000_SERC_c210831.nc' using WGET protocol.
# SUCCESS
#
# Loading input file list: 'Buildconf/datm.input_data_list'
# Check case OK
# submit_jobs case.run
# Submit job case.run
# Starting job script case.run
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Generating namelists for /home/user/CLM-NEON/SERC.transient
#   2021-10-26 13:34:32 atm
# Create namelist for component datm
#    Calling /opt/ncar/cesm2/cime/../components/cdeps/datm/cime_config/buildnml
# Found tower data for 2018-01-01 00:00:00 through 2021-06-01 00:00:00
# varname datafiles is already in stream mod dictionary
# varname year_first is already in stream mod dictionary
# varname year_last is already in stream mod dictionary
# varname year_align is already in stream mod dictionary
# varname dtlimit is already in stream mod dictionary
#   2021-10-26 13:34:33 lnd
# Create namelist for component clm
#    Calling /opt/ncar/cesm2/cime/../cime_config/buildnml
#   2021-10-26 13:34:33 ice
# Create namelist for component sice
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/sice/cime_config/buildnml
#   2021-10-26 13:34:33 ocn
# Create namelist for component socn
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/socn/cime_config/buildnml
#   2021-10-26 13:34:33 rof
# Create namelist for component srof
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/srof/cime_config/buildnml
#   2021-10-26 13:34:33 glc
# Create namelist for component sglc
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/sglc/cime_config/buildnml
#   2021-10-26 13:34:33 wav
# Create namelist for component swav
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/swav/cime_config/buildnml
#   2021-10-26 13:34:33 esp
# Create namelist for component sesp
#    Calling /opt/ncar/cesm2/cime/src/components/stub_comps_nuopc/sesp/cime_config/buildnml
#   2021-10-26 13:34:33 cpl
# Create namelist for component drv
#    Calling /opt/ncar/cesm2/cime/../components/cmeps/cime_config/buildnml
# Writing nuopc_runseq for components ['CPL', 'ATM', 'LND']
# -------------------------------------------------------------------------
#  - Prestage required restarts into /home/user/CLM-NEON/SERC.transient/run
#  - Case input data directory (DIN_LOC_ROOT) is /home/user/inputdata
#  - Checking for required input datasets in DIN_LOC_ROOT
# -------------------------------------------------------------------------
# run command is mpiexec  -n 1 /home/user/CLM-NEON/SCBI/bld/cesm.exe   >> cesm.log.$LID 2>&1
# Starting job script case.run
# Starting job script case.st_archive
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# Setting resource.RLIMIT_STACK to -1 from (-1, -1)
# No timing file found in run directory
# check for resubmit
# dout_s True
# mach container
# resubmit_num 0
# Submit job case.st_archive
# Starting job script case.st_archive
# st_archive starting
# moving /home/user/CLM-NEON/SERC.transient/run/atm.log.211026-133432.gz to /home/user/archive/SERC.transient/logs/atm.log.211026-133432.gz
# moving /home/user/CLM-NEON/SERC.transient/run/cesm.log.211026-133432.gz to /home/user/archive/SERC.transient/logs/cesm.log.211026-133432.gz
# moving /home/user/CLM-NEON/SERC.transient/run/drv.log.211026-133432.gz to /home/user/archive/SERC.transient/logs/drv.log.211026-133432.gz
# moving /home/user/CLM-NEON/SERC.transient/run/lnd.log.211026-133432.gz to /home/user/archive/SERC.transient/logs/lnd.log.211026-133432.gz
# moving /home/user/CLM-NEON/SERC.transient/run/med.log.211026-133432.gz to /home/user/archive/SERC.transient/logs/med.log.211026-133432.gz
# moving /home/user/CLM-NEON/SERC.transient/run/preview_run.log.211026-133432.gz to /home/user/archive/SERC.transient/logs/preview_run.log.211026-133432.gz
# -------------------------------------------
# Archiving restarts for date date(2021, 6, 1, 0, 0, 0)
# -------------------------------------------
# Archiving restarts for datm (atm)
# copying file /home/user/CLM-NEON/SERC.transient/run/SERC.transient.datm.r.2021-06-01-00000.nc to /home/user/archive/SERC.transient/rest/2021-06-01-00000/SERC.transient.datm.r.2021-06-01-00000.nc
# Archiving restarts for clm (lnd)
# copying file /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.r.2021-06-01-00000.nc to /home/user/archive/SERC.transient/rest/2021-06-01-00000/SERC.transient.clm2.r.2021-06-01-00000.nc
# Copying /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2021-06-01-00000.nc to /home/user/archive/SERC.transient/rest/2021-06-01-00000/SERC.transient.clm2.h1.2021-06-01-00000.nc
# Copying /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2021-05.nc to /home/user/archive/SERC.transient/rest/2021-06-01-00000/SERC.transient.clm2.h0.2021-05.nc
#  WARNING: ncdump -v locfnh /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.rh0.2021-06-01-00000.nc  failed rc=1
#     out=
#     err=ncdump: locfnh: No such variable
# copying file /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.rh0.2021-06-01-00000.nc to /home/user/archive/SERC.transient/rest/2021-06-01-00000/SERC.transient.clm2.rh0.2021-06-01-00000.nc
#  WARNING: ncdump -v locfnh /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.rh1.2021-06-01-00000.nc  failed rc=1
#     out=
#     err=ncdump: locfnh: No such variable
# copying file /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.rh1.2021-06-01-00000.nc to /home/user/archive/SERC.transient/rest/2021-06-01-00000/SERC.transient.clm2.rh1.2021-06-01-00000.nc
# Archiving restarts for drv (cpl)
# copying file /home/user/CLM-NEON/SERC.transient/run/SERC.transient.cpl.r.2021-06-01-00000.nc to /home/user/archive/SERC.transient/rest/2021-06-01-00000/SERC.transient.cpl.r.2021-06-01-00000.nc
# Archiving restarts for dart (esp)
# Archiving history files for datm (atm)
# Archiving history files for clm (lnd)
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2018-01.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2018-01.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2018-02.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2018-02.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2018-03.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2018-03.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2018-04.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2018-04.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2018-05.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2018-05.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2018-06.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2018-06.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2018-07.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2018-07.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2018-08.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2018-08.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2018-09.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2018-09.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2018-10.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2018-10.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2018-11.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2018-11.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2018-12.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2018-12.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2019-01.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2019-01.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2019-02.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2019-02.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2019-03.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2019-03.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2019-04.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2019-04.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2019-05.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2019-05.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2019-06.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2019-06.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2019-07.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2019-07.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2019-08.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2019-08.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2019-09.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2019-09.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2019-10.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2019-10.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2019-11.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2019-11.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2019-12.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2019-12.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2020-01.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2020-01.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2020-02.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2020-02.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2020-03.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2020-03.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2020-04.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2020-04.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2020-05.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2020-05.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2020-06.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2020-06.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2020-07.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2020-07.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2020-08.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2020-08.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2020-09.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2020-09.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2020-10.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2020-10.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2020-11.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2020-11.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2020-12.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2020-12.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2021-01.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2021-01.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2021-02.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2021-02.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2021-03.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2021-03.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2021-04.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2021-04.nc
# copying /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h0.2021-05.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h0.2021-05.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-01-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-01-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-02-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-02-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-03-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-03-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-04-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-04-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-05-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-05-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-06-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-06-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-07-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-07-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-08-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-08-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-09-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-09-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-10-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-10-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-11-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-11-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-12-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-12-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-13-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-13-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-14-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-14-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-15-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-15-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-16-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-16-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-17-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-17-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-18-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-18-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-19-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-19-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-20-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-20-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-21-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-21-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-22-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-22-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-23-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-23-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-24-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-24-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-25-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-25-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-26-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-26-00000.nc
# moving /home/user/CLM-NEON/SERC.transient/run/SERC.transient.clm2.h1.2018-01-27-00000.nc to /home/user/archive/SERC.transient/lnd/hist/SERC.transient.clm2.h1.2018-01-27-00000.nc
# ...
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-06-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-06-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-07-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-07-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-08-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-08-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-09-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-09-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-10-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-10-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-11-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-11-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-12-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-12-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-13-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-13-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-14-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-14-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-15-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-15-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-16-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-16-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-17-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-17-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-18-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-18-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-19-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-19-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-20-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-20-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-21-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-21-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-22-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-22-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-23-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-23-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-24-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-24-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-25-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-25-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-26-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-26-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-27-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-27-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-28-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-28-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-29-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-29-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-30-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-30-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-03-31-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-03-31-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-01-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-01-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-02-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-02-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-03-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-03-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-04-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-04-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-05-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-05-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-06-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-06-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-07-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-07-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-08-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-08-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-09-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-09-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-10-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-10-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-11-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-11-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-12-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-12-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-13-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-13-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-14-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-14-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-15-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-15-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-16-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-16-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-17-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-17-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-18-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-18-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-19-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-19-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-20-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-20-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-21-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-21-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-22-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-22-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-23-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-23-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-24-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-24-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-25-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-25-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-26-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-26-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-27-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-27-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-28-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-28-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-29-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-29-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-04-30-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-04-30-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-01-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-01-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-02-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-02-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-03-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-03-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-04-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-04-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-05-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-05-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-06-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-06-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-07-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-07-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-08-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-08-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-09-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-09-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-10-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-10-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-11-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-11-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-12-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-12-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-13-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-13-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-14-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-14-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-15-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-15-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-16-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-16-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-17-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-17-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-18-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-18-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-19-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-19-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-20-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-20-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-21-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-21-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-22-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-22-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-23-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-23-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-24-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-24-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-25-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-25-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-26-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-26-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-27-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-27-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-28-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-28-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-29-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-29-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-30-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-30-00000.nc
# moving /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-05-31-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-05-31-00000.nc
# copying /home/user/CLM-NEON/WOOD.transient/run/WOOD.transient.clm2.h1.2021-06-01-00000.nc to /home/user/archive/WOOD.transient/lnd/hist/WOOD.transient.clm2.h1.2021-06-01-00000.nc
# Archiving history files for drv (cpl)
# Archiving history files for dart (esp)
# st_archive completed
# Submitted job case.run with id None
# Submitted job case.st_archive with id None

# %% [markdown]
# <br><br>The model is done running when you see:
#
# >st_archive completed <br>
# >Submitted job case.run with id None <br>
# >Submitted job case.st_archive with id None <br>
#
# If you see this message, great! You've created and run CLM for the NEON tower you selected, and we'll look at simulated data next.
#
#
# **Note** that you can also run the above line of code in your terminal shell but you will need to point to the location of the file where you specify the NEON site and the output-root path:
#
# `run_neon.py --neon-sites <site> --output-root <path>`
#
# More details about setting up and modifying simulations will be available in an upcoming tutorial.
#
# Additional information about CLM is available [on the website](https://www.cesm.ucar.edu/models/cesm2/land/), including [technical documentation](https://escomp.github.io/ctsm-docs/versions/release-clm5.0/html/tech_note/index.html), a [user's guide](https://escomp.github.io/ctsm-docs/versions/release-clm5.0/html/users_guide/index.html), and a [quickstart guide](https://escomp.github.io/CESM/release-cesm2/quickstart.html#create-a-case) to running other model configurations.
# <br><br>
# ***

# %% [markdown]
# <h4> Optional </h4>
#
# If you would like to see additional and more advanced options for running NEON tower site simulations, many are listed in the python script you just executed. You can use the `--help` option to see more. <p>
#
# *Executing the below cell is optional and will print options available options in the `run_neon` python script*:

# %%
run_neon --help

# %% [markdown]
# ________
# <h2> 2. Explore CTSM model data </h2>
#
# *When your simulation completes, this step guides you through exploring the data.
# There are countless ways of analyzing and processing model data.
# The below steps show where model data were created and will create a plot from the model data.*
# ***

# %% [markdown]
# <h3> 2.1 Locate model data </h3>
#
# When a simulation completes, the data are transferred to the `archive` directory. In this directory, there are files that include data for every day of the simulation, as well as files that average model variables monthly. <p>
#
# *Run the code below to see a subset of the files listed.*

# %%
# !ls ~/archive/$site.transient/lnd/hist/*2018*.nc |head -20
# Out:
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h0.2018-01.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h0.2018-02.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h0.2018-03.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h0.2018-04.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h0.2018-05.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h0.2018-06.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h0.2018-07.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h0.2018-08.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h0.2018-09.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h0.2018-10.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h0.2018-11.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h0.2018-12.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h1.2018-01-01-00000.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h1.2018-01-02-00000.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h1.2018-01-03-00000.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h1.2018-01-04-00000.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h1.2018-01-05-00000.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h1.2018-01-06-00000.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h1.2018-01-07-00000.nc
# /home/user/archive/ABBY.transient/lnd/hist/ABBY.transient.clm2.h1.2018-01-08-00000.nc
# ls: write error: Broken pipe

# %% [markdown]
# Notice that each line includes the location of the file (`/home/user/archive/{simulation_name}/lnd/hist`) and file name. The file names are automatically generated and are composed of:
# * the simulation name, which includes:
#     * the NEON site
#     * the type of simulation (here the simulation is "transient", meaning the model ran for the full length of available data)
# * the date of simulated data
#
# The files are saved in netcdf format (denoted with the `.nc` file extension), a file format commonly used for storing large, multi-dimensional scientific variables.
# Netcdf files are platform independent and self-describing; each file includes metadata that describes the data, including: **variables**, **dimensions**, and **attributes**. We will explore the files more in the NEON_Simple_Visualization_Tutorial
#
# The NEON tower simulations generate two types of files:
# * `*h0*`: Variables that are averaged monthly. One file is available for every month of the simulation.
# * `*h1*`: Variables that are recorded every 30 minutes. Values are aggregated into one file for each day of the simulation. Each file includes 48 data points.
#
# *Note that you can also find the model data in the 'Simulation' folder on your desktop, which was created as part of this tutorial.*
# ****

# %% [markdown]
# <h3>2.2 Visualize the output </h3>
# Below we create a plot of simulated soil temperature.
#
# To do this, we use a predefined function, `quick_soil_profile` to check the soil_profile .
#
# This function points to the files we explored above and extracts one variable, soil temperature `TSOI` in this case, and plots the soil profile. The y-axis shows soil depth and the x-axis shows time, which is currently set for the year 2018. You can change the `year` variable from 2018 through the current year.

# %%
neon_site = "WOOD"
from neon_utils import plot_soil_profile_timeseries
sim_path = "/home/user/archive/"+neon_site+".transient/lnd/hist/"
case_name = neon_site+".transient.clm2"
year = 2018

plot_soil_profile_timeseries(sim_path, neon_site, case_name, 'TSOI', year)
# Out:
# All Simulation files: [ 365 files]
# Reading all simulation files [ 365 files] took: 32.787405252456665 s.

# %% [markdown]
# Now, let's make a similar plot for soil moisture (`H2OSOI`):

# %%
sim_path = "/home/user/archive/"+neon_site+".transient/lnd/hist/"
case_name = neon_site+".transient.clm2"
year = 2018

plot_soil_profile_timeseries(sim_path, neon_site, case_name, 'H2OSOI', year)
# Out:
# All Simulation files: [ 365 files]
# Reading all simulation files [ 365 files] took: 40.205222606658936 s.

# %% [markdown]
# ### Congratulations!
# You have now completed a NEON tower simulation, located the files, and made a plot from the simulation data.
#
# Additional examples of visualizations and evaluation of your NEON simulation against NEON observations are available in the next tutorial, `NEON_Visualization_Tutorial`.
